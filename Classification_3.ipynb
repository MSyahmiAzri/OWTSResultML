# %% [markdown]
# <a href="https://colab.research.google.com/github/MSyahmiAzri/OWTSResultML/blob/main/Classification_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **MACHINE LEARNING CLASSIFICATION 3**
#
#
# THREE TYPE OF OUTPUTS:
# 1. MONITORING
# 2. NORMAL
# 3. REPAIR

# %% [markdown]
# **1. IMPORTING DATA**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# Replace the file ID with your own
file_id = '1fFe63sxH6kGwHdHwjweC5oUe-lv0lq6y'
link = f'https://drive.google.com/uc?id={file_id}'
df = pd.read_excel(link)

# %% [markdown]
# 2. CHECKING DATA

# %%
df.head()
# Out:
#    BIL STATION  TEST DATE SOURCE\nPMU/PPU/SSU FEEDER NO  \
# 0  704   BANGI 2022-01-05                KJGU         6
# 1  705   BANGI 2022-01-24                SEC9         2
# 2  706   BANGI 2022-01-24                ABBA         4
# 3  707   BANGI 2022-01-25                BRNG         2
# 4  708   BANGI 2022-01-26                 UPM         3
#
#                       TEST FROM CABLE ID                        TEST TO  \
# 0            PE TMN MEWAH INDAH   B03423                  PE NG TRADING
# 1       PE BANDAR BARU BANGI 18   B06023  PE RAWATAN SISA AIR SEKSYEN 9
# 2                 PE SG MERAB 3   B03804      PE JALAN PBP 4 PRECINT 17
# 3       PE TASEK KESUMA FASA 3B   B05132             PE TREATMENT PLANT
# 4  PE APARTMENT KANTAN COURT B2   B07766                     PE KG AMAN
#
#   CABLE TYPE     SIZE (mm2)  ...        CAT1        CAT2       CAT3    CAT4  \
# 0       XLPE         240MMP  ...  MONITORING  MONITORING  UNHEALTHY  NORMAL
# 1      MIXED  240MMP/300MMP  ...      NORMAL      NORMAL    HEALTHY  NORMAL
# 2       XLPE         240MMP  ...         MWT      REPAIR  UNHEALTHY  NORMAL
# 3      MIXED  240MMP/300MMP  ...         MWT      REPAIR  UNHEALTHY  NORMAL
# 4       XLPE         240MMP  ...  MONITORING  MONITORING  UNHEALTHY  NORMAL
#
#      CAT5  CATEGORY DEFECT        PD TYPE       RECOMMENDATION  \
# 0  NORMAL            JOINT  CONCENTRATION  MONITORING & RETEST
# 1  NORMAL        NO DEFECT      SCATTERED              VLF/MWT
# 2  REPAIR        NO DEFECT      SCATTERED  MONITORING & RETEST
# 3  REPAIR        NO DEFECT          NO PD  MONITORING & RETEST
# 4  NORMAL            JOINT  CONCENTRATION  MONITORING & RETEST
#
#    RECOMMENDATION (FREE TEXT)  MONITORING DURATION
# 0                 RETEST OWTS              6 BULAN
# 1                    VLF/ MWT              6 BULAN
# 2                 RETEST OWTS             12 BULAN
# 3                 RETEST OWTS             12 BULAN
# 4                 RETEST OWTS              6 BULAN
#
# [5 rows x 40 columns]

# %% [markdown]
# 3. CHECKING DATA DIMENSIONS

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3890 entries, 0 to 3889
# Data columns (total 40 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   BIL                         3887 non-null   object
#  1   STATION                     3890 non-null   object
#  2   TEST DATE                   3890 non-null   datetime64[ns]
#  3   SOURCE
# PMU/PPU/SSU          3889 non-null   object
#  4   FEEDER NO                   3890 non-null   object
#  5   TEST FROM                   3890 non-null   object
#  6   CABLE ID                    3890 non-null   object
#  7   TEST TO                     3890 non-null   object
#  8   CABLE TYPE                  3890 non-null   object
#  9   SIZE (mm2)                  3890 non-null   object
#  10  CORE                        3890 non-null   object
#  11  LENGTH(m)                   3890 non-null   int64
#  12  DAR RED                     3890 non-null   float64
#  13  DAR YELLOW                  3889 non-null   object
#  14  DAR BLUE                    3889 non-null   object
#  15  MIN DAR                     3890 non-null   float64
#  16  DAR<1?                      3890 non-null   object
#  17  ALL PHASE DAR < 1?          3890 non-null   object
#  18  IR R-E (60s)                3890 non-null   float64
#  19  IR Y-E (60s)                3890 non-null   float64
#  20  IR B-E (60s)                3890 non-null   float64
#  21  UNBALANCED?                 3890 non-null   object
#  22  % UNBALANCED                3890 non-null   float64
#  23  MIN IR                      3890 non-null   float64
#  24  IR<100?                     3890 non-null   object
#  25  ALL PHASE IR<100            3890 non-null   object
#  26  ANALISA IR & PIDAR          3890 non-null   object
#  27  RL                          3890 non-null   float64
#  28  KATERGORI ANALISA KABEL     3890 non-null   object
#  29  SEVERITY                    3890 non-null   float64
#  30  CAT1                        3890 non-null   object
#  31  CAT2                        3890 non-null   object
#  32  CAT3                        3890 non-null   object
#  33  CAT4                        3890 non-null   object
#  34  CAT5                        3890 non-null   object
#  35  CATEGORY DEFECT             3888 non-null   object
#  36  PD TYPE                     3890 non-null   object
#  37  RECOMMENDATION              3890 non-null   object
#  38  RECOMMENDATION (FREE TEXT)  3888 non-null   object
#  39  MONITORING DURATION         3885 non-null   object
# dtypes: datetime64[ns](1), float64(9), int64(1), object(29)
# memory usage: 1.2+ MB

# %% [markdown]
# 4. SCATTERPLOT

# %%
sns.scatterplot(x='MIN IR', y='SEVERITY', hue='CAT2', data=df)
plt.xlim([0, 2000])
#plt.ylim([0,50000])
plt.show()

# %% [markdown]
# 5. PIVOT TABLE

# %%
pivot_table = df.pivot_table(index=['ANALISA IR & PIDAR'], columns=['CAT2'], aggfunc='size', fill_value=0)
print(pivot_table)
# Out:
# CAT2                     MONITORING  NORMAL  REPAIR
# ANALISA IR & PIDAR
# DAR<1                            75       0     188
# DAR<1,IR<100                     63       0      93
# DAR<1,IR<100,UNBALANCED          78       0     209
# DAR<1,UNBALANCED                 83       0     209
# IR<100                          190       0     448
# IR<100,UNBALANCED               156       0     405
# OK                              326     367     395
# UNBALANCED                      196       0     409

# %% [markdown]
# 5. BUILDING MACHINE LEARNING WITH RESULTS

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

# Assuming 'df' is your DataFrame
features = df[['MIN IR','LENGTH(m)','% UNBALANCED','MIN DAR']]
target = df['CAT2']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=0)

# Standardize the features
#scaler = StandardScaler()
#X_train = scaler.fit_transform(X_train)
#X_test = scaler.transform(X_test)

# Create a Random Forest classifier
model = RandomForestClassifier()
# Train the model
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# Generate the confusion matrix
cm = confusion_matrix(y_test, y_pred)
cr = classification_report(y_test, y_pred)

# Print the confusion matrix
print("Confusion Matrix:")
print(cm)
print(cr)
# Out:
# Accuracy: 0.6709511568123393
# Confusion Matrix:
# [[ 48  23 161]
#  [  9  60   5]
#  [ 52   6 414]]
#               precision    recall  f1-score   support
#
#   MONITORING       0.44      0.21      0.28       232
#       NORMAL       0.67      0.81      0.74        74
#       REPAIR       0.71      0.88      0.79       472
#
#     accuracy                           0.67       778
#    macro avg       0.61      0.63      0.60       778
# weighted avg       0.63      0.67      0.63       778

# %% [markdown]
# 6. TESTING THE MODEL WITH 2024 DATA

# %%
# Assuming 'new_df' is your new DataFrame with the same structure as 'df'

file_id_new = '1EgsiIstrR0Z1tk9WazQ6gj7NVr6XVe6A'
link_new = f'https://drive.google.com/uc?id={file_id_new}'
new_df = pd.read_excel(link_new)

#from sklearn.preprocessing import LabelEncoder , OneHotEncoder
#labelencoder_x=LabelEncoder()
#new_df['KATERGORI ANALISA KABEL']=labelencoder_x.fit_transform(new_df['KATERGORI ANALISA KABEL'])
new_features = new_df[['MIN IR','LENGTH(m)','% UNBALANCED','MIN DAR']]
new_target = new_df['CAT2']

# Make predictions on the new dataset using the trained model
new_y_pred = model.predict(new_features)


# Evaluate the model on the new dataset
new_accuracy = accuracy_score(new_target, new_y_pred)
print("Accuracy on new dataset:", new_accuracy)

# Generate the confusion matrix for the new dataset
new_cm = confusion_matrix(new_target, new_y_pred)

# Print the confusion matrix for the new dataset
print("Confusion Matrix on new dataset:")
print(new_cm)

new_cr = classification_report(new_target, new_y_pred)
print(new_cr)
# Out:
# Accuracy on new dataset: 0.664796633941094
# Confusion Matrix on new dataset:
# [[ 32  13 153]
#  [ 10  21   2]
#  [ 55   6 421]]
#               precision    recall  f1-score   support
#
#   MONITORING       0.33      0.16      0.22       198
#       NORMAL       0.53      0.64      0.58        33
#       REPAIR       0.73      0.87      0.80       482
#
#     accuracy                           0.66       713
#    macro avg       0.53      0.56      0.53       713
# weighted avg       0.61      0.66      0.62       713

# %% [markdown]
# 7. EXPORTING 2024 DATA TEST

# %%
result_df = pd.DataFrame({
    'STATION': new_df['STATION'],
    'LINK NO' : new_df['CABLE ID'],
    '% UNBALANCED': new_df['% UNBALANCED'],
    'ANALISA PIDAR': new_df['ANALISA IR & PIDAR'],
    'MIN IR': new_df['MIN IR'],
    'LENGTH(m)': new_df['LENGTH(m)'],
    'RL': new_df['RL'],
    'MIN DAR': new_df['MIN DAR'],
    'SEVERITY': new_df['SEVERITY'],
    'CAT1': new_df['CAT1'],
    'Actual Kategori': new_target,
    'Predicted Kategori': new_y_pred
})

result_df
# Out:
#      STATION LINK NO  % UNBALANCED            ANALISA PIDAR  MIN IR  \
# 0      KLANG  K20324      0.310493                   IR<100    32.2
# 1      KLANG  K24478      0.919641         DAR<1,UNBALANCED   626.0
# 2      KLANG  K24765      0.417722                    DAR<1   552.0
# 3      KLANG  K14103      0.668750               UNBALANCED  1060.0
# 4      KLANG  K14104      0.462451                       OK  4080.0
# ..       ...     ...           ...                      ...     ...
# 708  PUCHONG  J11012      0.623762               UNBALANCED  1140.0
# 709  PUCHONG  J50915      0.406294                       OK  8490.0
# 710  PUCHONG  J49125      0.263846                    DAR<1  9570.0
# 711  PUCHONG  J40014      0.638554         DAR<1,UNBALANCED  1500.0
# 712  PUCHONG  J39578      0.877554  DAR<1,IR<100,UNBALANCED    85.1
#
#      LENGTH(m)          RL  MIN DAR SEVERITY        CAT1 Actual Kategori  \
# 0         3220    103.6840     1.09    5.108      REPAIR          REPAIR
# 1         1608   1006.6080     0.91   0.7112         MWT          REPAIR
# 2          364    200.9280     0.94        0         MWT          REPAIR
# 3          280    296.8000     1.01   3.9745  MONITORING      MONITORING
# 4          416   1697.2800     1.04        0         MWT          REPAIR
# ..         ...         ...      ...      ...         ...             ...
# 708        633    721.6200     1.02      3.4  MONITORING      MONITORING
# 709       2793  23712.5700     1.03      2.3  MONITORING      MONITORING
# 710        327   3129.3900     0.94      2.3  MONITORING      MONITORING
# 711        674   1011.0000     0.89      1.2         MWT          REPAIR
# 712       1965    167.2215     0.84     1.31         MWT          REPAIR
#
#     Predicted Kategori
# 0               REPAIR
# 1               REPAIR
# 2               REPAIR
# 3               REPAIR
# 4               REPAIR
# ..                 ...
# 708             REPAIR
# 709             REPAIR
# 710             REPAIR
# 711             REPAIR
# 712         MONITORING
#
# [713 rows x 12 columns]
